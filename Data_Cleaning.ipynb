# %%
import pandas as pd

# %%
train_df = pd.read_csv(r'C:\Users\user\Desktop\birdclef-2022\train_df.csv')
test_df = pd.read_csv(r'C:\Users\user\Desktop\birdclef-2022\test_df.csv')

# %%
train_df.head()
# Out:
#   primary_label secondary_labels                       type  latitude  \
# 0        houfin       ['gamqua']  ['adult', 'male', 'song']   31.9938
# 1        houfin       ['houspa']                   ['call']   19.3910
# 2        spodov               []                   ['song']    1.5249
# 3        houfin               []  ['adult', 'male', 'song']   17.0166
# 4        houfin               []                   ['call']   45.5582
#
#    longitude         scientific_name   common_name              author  \
# 0  -112.8431    Haemorhous mexicanus   House Finch  Richard E. Webster
# 1   -99.2439    Haemorhous mexicanus   House Finch    Manuel Grosselet
# 2   110.3123  Streptopelia chinensis  Spotted Dove          Hobart WQH
# 3   -96.7262    Haemorhous mexicanus   House Finch  Omar Suárez García
# 4  -122.6928    Haemorhous mexicanus   House Finch     Thomas Magarian
#
#                                              license  rating   time  \
# ...

# %%
test_df.head()
# Out:
#   primary_label      secondary_labels  \
# 0        commyn            ['houspa']
# 1       warwhe1                    []
# 2        commyn                    []
# 3        zebdov                    []
# 4        houfin  ['calqua', 'houfin']
#
#                                                type  latitude  longitude  \
# 0                                          ['song']  -25.8401    28.2612
# 1                                          ['call']   28.4468   129.5900
# 2                                          ['call']   43.9209    67.6331
# 3  ['call', 'display call or song', 'male', 'song']    1.5252   110.3124
# 4                                          ['call']   32.6809  -116.8189
#
#         scientific_name         common_name            author  \
# 0  Acridotheres tristis         Common Myna   Faansie Peacock
# 1   Zosterops japonicus  Warbling White-eye        Guy Kirwan
# 2  Acridotheres tristis         Common Myna  Albert Lastukhin
# ...

# %% [markdown]
# # Checking for missing values

# %%
print(train_df.isnull().sum())
# Out:
# primary_label       0
# secondary_labels    0
# type                0
# latitude            0
# longitude           0
# scientific_name     0
# common_name         0
# author              0
# license             0
# rating              0
# time                0
# url                 0
# filename            0
# path                0
# frames              0
# sr                  0
# duration            0
# dtype: int64

# %%
print(test_df.isnull().sum())
# Out:
# primary_label       0
# secondary_labels    0
# type                0
# latitude            0
# longitude           0
# scientific_name     0
# common_name         0
# author              0
# license             0
# rating              0
# time                0
# url                 0
# filename            0
# path                0
# frames              0
# sr                  0
# duration            0
# dtype: int64

# %% [markdown]
# # Dropping columns

# %%
columns_to_drop = ['secondary_labels', 'scientific_name', 'common_name', 'author', 'time', 'url']

# %%
train_df.drop(columns=columns_to_drop, inplace=True)

# %%
test_df.drop(columns=columns_to_drop, inplace=True)

# %%
train_df.head()
# Out:
#   primary_label                       type  latitude  longitude  \
# 0        houfin  ['adult', 'male', 'song']   31.9938  -112.8431
# 1        houfin                   ['call']   19.3910   -99.2439
# 2        spodov                   ['song']    1.5249   110.3123
# 3        houfin  ['adult', 'male', 'song']   17.0166   -96.7262
# 4        houfin                   ['call']   45.5582  -122.6928
#
#                                              license  rating  \
# 0  Creative Commons Attribution-NonCommercial-Sha...     3.5
# 1  Creative Commons Attribution-NonCommercial-Sha...     4.5
# 2  Creative Commons Attribution-NonCommercial-Sha...     1.5
# 3  Creative Commons Attribution-NonCommercial-Sha...     4.5
# 4  Creative Commons Attribution-NonCommercial-Sha...     0.0
#
#               filename                                               path  \
# 0  houfin/XC621698.ogg  C:\Users\user\Desktop\birdclef-2022\train_audi...
# ...

# %%
train_df.to_csv(r'C:\Users\user\Desktop\birdclef-2022\train_df_clean.csv', index=False, encoding='utf-8')

# %%
test_df.to_csv(r'C:\Users\user\Desktop\birdclef-2022\test_df_clean.csv', index=False, encoding='utf-8')
